# %%
# standard imports
import json
from pathlib import Path
from itertools import chain

# third party imports
import dask.dataframe as dd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# constants
DATAFRAMES = Path('./dataframes')

# %%
# load hdf files
dfs = {file_.stem: dd.read_hdf(str(file_), key='df-*')
        for file_ in DATAFRAMES.glob('*.hdf')}

# %% [markdown]
# ## Page Inits

# %%
# variables for easy referencing
pi = dfs['PageInits'].compute()

# %%
pi = pi.sort_values(['publisherUserId', 'request.requestedAt'])

# %%
pi.head()
# Out:
#        browserRequest.screenHeight  browserRequest.screenPixelDepth  \
# 8936                           960                                0
# 4946                           912                               24
# 4965                           912                               24
# 14251                          912                               24
# 14264                          912                               24
#
#        browserRequest.screenWidth                          campaignReferrer  \
# 8936                         1280  a88b7dcd1a9e3e17770bbaa6d7515b31a2d7e85d
# 4946                         1368  d0941e68da8f38151ff86a61fc59f7c5cf9fcaa2
# 4965                         1368  d0941e68da8f38151ff86a61fc59f7c5cf9fcaa2
# 14251                        1368  d0941e68da8f38151ff86a61fc59f7c5cf9fcaa2
# 14264                        1368  d0941e68da8f38151ff86a61fc59f7c5cf9fcaa2
#
#        deviceVentileGroup       pageId                  pageInitializationId  \
# 8936                   10  flight.home  aa6621a4-2d8b-4c4e-be91-f0dbe23eb3d0
# 4946                    2  flight.home  ec4281fa-dd7a-4d82-ab43-ff5bbcebe5d6
# 4965                    0  flight.list  20397260-1a09-4e54-86a0-e37085858ad1
# 14251                  14  flight.home  b5df6141-a133-49b2-8c55-ff4ed4fe3c58
# 14264                   0  flight.list  f6acbd41-21ad-4eac-b3c0-cba9fadbb87b
#
#       productCategoryType productPath  \
# 8936              FLIGHTS     FLIGHTS
# 4946              FLIGHTS     FLIGHTS
# 4965              FLIGHTS     FLIGHTS
# 14251             FLIGHTS     FLIGHTS
# 14264             FLIGHTS     FLIGHTS
#
#                                 publisherUserId  \
# 8936   00001d27aa482ad2b982296c016365eed6441502
# 4946   000030a6d85ad2effe150c581b1735ce243ab4ab
# 4965   000030a6d85ad2effe150c581b1735ce243ab4ab
# 14251  000030a6d85ad2effe150c581b1735ce243ab4ab
# 14264  000030a6d85ad2effe150c581b1735ce243ab4ab
#
#                    request.requestedAt segmentationType
# 8936  2019-10-17 09:54:25.819000+00:00   LOW_CONVERTING
# 4946  2019-08-05 02:44:42.940000+00:00   LOW_CONVERTING
# 4965  2019-08-05 02:45:10.157000+00:00   LOW_CONVERTING
# 14251 2019-10-20 17:11:21.537000+00:00   LOW_CONVERTING
# 14264 2019-10-20 17:12:37.846000+00:00   LOW_CONVERTING

# %%
# convert times to UTC
pi['request.requestedAt'] = pi['request.requestedAt'].dt.tz_convert(None)

# group by publisher user id and get time difference
pi['request.nextRequestedAt'] = pi.groupby('publisherUserId')['request.requestedAt'].shift(-1)
pi['request.lastRequestedAt'] = pi.groupby('publisherUserId')['request.requestedAt'].shift(1)
pi['request.timeDifference'] = (pi['request.requestedAt'] - pi['request.lastRequestedAt']).dt.total_seconds() / 60
pi[['request.requestedAt','request.lastRequestedAt','request.timeDifference']].head()
# Out:
#           request.requestedAt request.lastRequestedAt  request.timeDifference
# 8936  2019-10-17 09:54:25.819                     NaT                     NaN
# 4946  2019-08-05 02:44:42.940                     NaT                     NaN
# 4965  2019-08-05 02:45:10.157 2019-08-05 02:44:42.940                0.453617
# 14251 2019-10-20 17:11:21.537 2019-08-05 02:45:10.157           110306.189667
# 14264 2019-10-20 17:12:37.846 2019-10-20 17:11:21.537                1.271817

# %%
# create session ids
pi['sessionId'] = pi.groupby('publisherUserId')['request.timeDifference'].transform(lambda x: x >= 15).cumsum() + 1

# %%
preview_cols = ['publisherUserId','request.requestedAt','request.lastRequestedAt','request.nextRequestedAt','request.timeDifference',
                'sessionId']
pi.loc[pi['publisherUserId'] == '000030a6d85ad2effe150c581b1735ce243ab4ab', preview_cols].reset_index().sort_values('request.requestedAt')
# Out:
#     index                           publisherUserId     request.requestedAt  \
# 0    4946  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-08-05 02:44:42.940
# 1    4965  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-08-05 02:45:10.157
# 2   14251  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:11:21.537
# 3   14264  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:12:37.846
# 4   14315  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:14:11.924
# 5   14365  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:15:04.925
# 6   14331  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:15:16.656
# 7   14403  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:17:00.160
# 8   14450  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:17:49.034
# 9   14619  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:24:21.640
# 10  14677  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:25:39.265
# 11  15134  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 17:37:28.340
# 12   7101  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 18:04:43.568
# 13   7147  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 18:04:51.681
# 14   7165  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 18:07:02.304
# 15   7188  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 18:07:09.749
# 16   7887  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 18:29:52.840
# 17   7892  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-20 18:30:17.263
# 18   3637  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-22 00:20:55.337
# 19   3638  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-22 00:20:58.621
# 20   3712  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-22 00:21:15.624
# 21   3714  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-22 00:21:20.723
# 22   3730  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-22 00:21:42.216
# 23   3760  000030a6d85ad2effe150c581b1735ce243ab4ab 2019-10-22 00:22:30.588
#
#    request.lastRequestedAt request.nextRequestedAt  request.timeDifference  \
# 0                      NaT 2019-08-05 02:45:10.157                     NaN
# 1  2019-08-05 02:44:42.940 2019-10-20 17:11:21.537                0.453617
# 2  2019-08-05 02:45:10.157 2019-10-20 17:12:37.846           110306.189667
# 3  2019-10-20 17:11:21.537 2019-10-20 17:14:11.924                1.271817
# 4  2019-10-20 17:12:37.846 2019-10-20 17:15:04.925                1.567967
# 5  2019-10-20 17:14:11.924 2019-10-20 17:15:16.656                0.883350
# 6  2019-10-20 17:15:04.925 2019-10-20 17:17:00.160                0.195517
# 7  2019-10-20 17:15:16.656 2019-10-20 17:17:49.034                1.725067
# 8  2019-10-20 17:17:00.160 2019-10-20 17:24:21.640                0.814567
# 9  2019-10-20 17:17:49.034 2019-10-20 17:25:39.265                6.543433
# 10 2019-10-20 17:24:21.640 2019-10-20 17:37:28.340                1.293750
# 11 2019-10-20 17:25:39.265 2019-10-20 18:04:43.568               11.817917
# 12 2019-10-20 17:37:28.340 2019-10-20 18:04:51.681               27.253800
# 13 2019-10-20 18:04:43.568 2019-10-20 18:07:02.304                0.135217
# 14 2019-10-20 18:04:51.681 2019-10-20 18:07:09.749                2.177050
# 15 2019-10-20 18:07:02.304 2019-10-20 18:29:52.840                0.124083
# 16 2019-10-20 18:07:09.749 2019-10-20 18:30:17.263               22.718183
# 17 2019-10-20 18:29:52.840 2019-10-22 00:20:55.337                0.407050
# 18 2019-10-20 18:30:17.263 2019-10-22 00:20:58.621             1790.634567
# 19 2019-10-22 00:20:55.337 2019-10-22 00:21:15.624                0.054733
# 20 2019-10-22 00:20:58.621 2019-10-22 00:21:20.723                0.283383
# 21 2019-10-22 00:21:15.624 2019-10-22 00:21:42.216                0.084983
# 22 2019-10-22 00:21:20.723 2019-10-22 00:22:30.588                0.358217
# 23 2019-10-22 00:21:42.216                     NaT                0.806200
#
#     sessionId
# 0           1
# 1           1
# 2           2
# 3           2
# 4           2
# 5           2
# 6           2
# 7           2
# 8           2
# 9           2
# 10          2
# 11          2
# 12          3
# 13          3
# 14          3
# 15          3
# 16          4
# 17          4
# 18          5
# 19          5
# 20          5
# 21          5
# 22          5
# 23          5

# %%
pi.to_hdf(f'{str(DATAFRAMES)}/PageInits.hdf', key='pi', format='table')

# %% [markdown]
# ## Conversions

# %%
cv = dfs['Conversions'].compute()

# %%
cv = cv.sort_values(['publisherUserId', 'request.requestedAt'])

# %%
cv = cv.drop(columns=['entityId'])

# %%
# fix request date
cv['request.requestedAt'] = pi['request.requestedAt'].dt.tz_convert(None)

# %%
# group by conversions by all columns outside request.requestId / 'request.requestedAt'
cols_to_group = list(set(cv.columns.values) - {'request.requestId', 'request.requestedAt'})
cv = cv.groupby(cols_to_group).agg({'request.requestedAt': 'max', 'request.requestId': 'count'}).reset_index()

# %%
cv.head()
# Out:
#   tripType  browserRequest.screenWidth  browserRequest.screenPixelDepth  \
# 0  ONE_WAY                         360                               32
# 1  ONE_WAY                         820                               24
# 2  ONE_WAY                         840                               24
# 3  ONE_WAY                         900                               24
# 4  ONE_WAY                         912                               24
#
#             travelDateStart carPickupAirportCode  \
# 0 2020-01-01 00:00:00+00:00                  PER
# 1 2019-12-18 00:00:00+00:00                  JFK
# 2 2019-12-14 00:00:00+00:00                  SFO
# 3 2019-09-07 00:00:00+00:00                  NYC
# 4 2019-09-04 00:00:00+00:00                  CHI
#
#                             publisherUserId               pageId  \
# 0  7d84adfbe42943c4955bb41cbb5eb1f6100b163f  flight.confirmation
# 1  3523552726bdb5429dd2fec1d63fde64e1330692  flight.confirmation
# 2  05210d5ad8aba5cf2474cfc9ae9e149b00fc705a  flight.confirmation
# 3  fa3cd0ddd38ec5505e4b02b9cbd85cb76df0ccc8  flight.confirmation
# 4  4297b211f810c00904947b1d5e9a1234cd995936  flight.confirmation
#
#   carDropoffAirportCode destination  travelers             travelDateEnd  \
# 0                   SZX         SZX          1 2020-01-01 00:00:00+00:00
# 1                   AMD         AMD          1 2019-12-18 00:00:00+00:00
# 2                   BZE         BZE          1 2019-12-14 00:00:00+00:00
# 3                   EDI         EDI          1 2019-09-07 00:00:00+00:00
# 4                   NYC         NYC          1 2019-09-04 00:00:00+00:00
#
#   origination  browserRequest.screenHeight  cookieSize  \
# 0         PER                          720          69
# 1         JFK                          615         125
# 2         SFO                          526          69
# 3         NYC                         1600        2251
# 4         CHI                          608        2419
#
#                                     orderId  \
# 0  7f1007c8a2ca9067371a2c53b083648c8a68d6de
# 1  c2298b7e05f288ece87077c28ddfa3cae182f8e8
# 2  0a19d48945becaa184b6d6d2a3e38a7db476fa18
# 3  ab8d76d56f53b74e7f92f017c3d02c4b674b40e3
# 4  31e82d79133cab94e7b721f764299f06fd15a2af
#
#                        advancePurchaseRangeType productCategoryType  \
# 0           WEEKDAY_TRAVEL_GREATER_THAN_21_DAYS             FLIGHTS
# 1           WEEKDAY_TRAVEL_GREATER_THAN_21_DAYS             FLIGHTS
# 2           WEEKEND_TRAVEL_GREATER_THAN_21_DAYS             FLIGHTS
# 3  WEEKEND_TRAVEL_LESS_THAN_OR_EQUAL_TO_21_DAYS             FLIGHTS
# 4  WEEKDAY_TRAVEL_LESS_THAN_OR_EQUAL_TO_21_DAYS             FLIGHTS
#
#                request.requestedAt  request.requestId
# 0 2019-10-13 05:31:18.203000+00:00                  1
# 1 2019-10-04 12:41:20.292000+00:00                  4
# 2 2019-08-19 21:46:35.621000+00:00                  4
# 3 2019-08-21 18:37:16.623000+00:00                  4
# 4 2019-09-01 21:43:39.637000+00:00                  4

# %%
# create days from travel columns
cv['daysFromTravel'] = (cv['travelDateStart'] - cv['request.requestedAt']).dt.days

# %%
preview_cols = ['publisherUserId','request.requestedAt','travelDateStart','daysFromTravel']
cv[preview_cols].head()
# Out:
#                             publisherUserId              request.requestedAt  \
# 0  7d84adfbe42943c4955bb41cbb5eb1f6100b163f 2019-10-13 05:31:18.203000+00:00
# 1  3523552726bdb5429dd2fec1d63fde64e1330692 2019-10-04 12:41:20.292000+00:00
# 2  05210d5ad8aba5cf2474cfc9ae9e149b00fc705a 2019-08-19 21:46:35.621000+00:00
# 3  fa3cd0ddd38ec5505e4b02b9cbd85cb76df0ccc8 2019-08-21 18:37:16.623000+00:00
# 4  4297b211f810c00904947b1d5e9a1234cd995936 2019-09-01 21:43:39.637000+00:00
#
#             travelDateStart  daysFromTravel
# 0 2020-01-01 00:00:00+00:00              79
# 1 2019-12-18 00:00:00+00:00              74
# 2 2019-12-14 00:00:00+00:00             116
# 3 2019-09-07 00:00:00+00:00              16
# 4 2019-09-04 00:00:00+00:00               2

# %%
cv.loc[cv['publisherUserId'] == '0002eaacc4a7f7c079e90bc88e9d3faea72c9dea', :]
# Out:
#       tripType  browserRequest.screenWidth  browserRequest.screenPixelDepth  \
# 12585  ONE_WAY                        1680                               24
#
#                 travelDateStart carPickupAirportCode  \
# 12585 2019-10-19 00:00:00+00:00                  FLL
#
#                                 publisherUserId               pageId  \
# 12585  0002eaacc4a7f7c079e90bc88e9d3faea72c9dea  flight.confirmation
#
#       carDropoffAirportCode destination  travelers             travelDateEnd  \
# 12585                   SEA         SEA          1 2019-10-19 00:00:00+00:00
#
#       origination  browserRequest.screenHeight  cookieSize  \
# 12585         FLL                         1050         125
#
#                                         orderId  \
# 12585  29bf57d0e19a38a4bdd12799d2ca5f818d7de878
#
#                            advancePurchaseRangeType productCategoryType  \
# 12585  WEEKEND_TRAVEL_LESS_THAN_OR_EQUAL_TO_21_DAYS             FLIGHTS
#
#                    request.requestedAt  request.requestId  daysFromTravel
# 12585 2019-10-17 00:42:13.787000+00:00                  4               1

# %%
cv = cv.sort_values(['publisherUserId', 'request.requestedAt'])
cv.to_hdf(f'{str(DATAFRAMES)}/Conversions.hdf', key='cv', format='table')

# %% [markdown]
# ## Client Side Infos

# %%
csi = dd.read_hdf(f'{str(DATAFRAMES)}/ClientSideInfos.hdf', key='df-*')
csi = csi.compute()

# %%
csi.head()
# Out:
#                                     clientId                       clientTime  \
# 0   3ee55b375ac83d05d90a1516006029101f250cc7 2019-08-20 18:59:56.156000+00:00
# 1   3ee55b375ac83d05d90a1516006029101f250cc7 2019-08-20 18:59:59.639000+00:00
# 6   e5fff86f6a9d343557439f4a6af9ea68f84a9e83 2019-08-20 18:59:58.927000+00:00
# 15  e5fff86f6a9d343557439f4a6af9ea68f84a9e83 2019-08-20 19:00:05.270000+00:00
# 20  e5fff86f6a9d343557439f4a6af9ea68f84a9e83 2019-08-20 19:00:04.455000+00:00
#
#                          customDimensions.clickTarget  \
# 0                   div#slider-control.slider-control
# 1                                   div.slider-center
# 6   input#destination1.form-control.lg.ng-pristine...
# 15                                        a#logOutBtn
# 20                                     div.ng-binding
#
#     customDimensions.documentHeight  customDimensions.documentWidth  \
# 0                              4132                            1503
# 1                              4132                            1503
# 6                              3180                            1831
# 15                             2990                            1506
# 20                             3180                            1831
#
#     customDimensions.label  customDimensions.pageX  customDimensions.pageY  \
# 0   FILTERS_DEPARTURE_TIME                     304                    1530
# 1   FILTERS_DEPARTURE_TIME                     329                    1519
# 6       FLIGHT_DESTINATION                     608                     277
# 15          NAV_BAR_LOG_IN                    1199                     226
# 20      FLIGHT_DESTINATION                     663                     307
#
#                             customDimensions.selector  \
# 0   #filtersSection > section > div.card > article...
# 1   #filtersSection > section > div.card > article...
# 6   #flightSearchTemplateScope > div.flight-search...
# 15  #top > div.container > div > div:nth-child(2) ...
# 20  #flightSearchTemplateScope > div.flight-search...
#
#     customDimensions.viewportHeight  customDimensions.viewportWidth  \
# 0                               655                            1520
# 1                               655                            1520
# 6                               938                            1847
# 15                              738                            1522
# 20                              938                            1847
#
#                               name       pageId  \
# 0   interaction_monitor_knownClick  flight.list
# 1   interaction_monitor_knownClick  flight.list
# 6   interaction_monitor_knownClick  flight.home
# 15  interaction_monitor_knownClick  flight.list
# 20  interaction_monitor_knownClick  flight.home
#
#                     pageInitializationId  \
# 0   59bceb8a-5d99-42c3-8ea1-d078142b1f1e
# 1   59bceb8a-5d99-42c3-8ea1-d078142b1f1e
# 6   5a08f086-ebbc-4e01-88bd-06caad09b49d
# 15  33dd1c3a-dd32-4d50-9401-5b71f8542b42
# 20  5a08f086-ebbc-4e01-88bd-06caad09b49d
#
#                              publisherUserId              request.requestedAt
# 0   8c40fdf063e02ad3b57a3c99a8348338dd0474da 2019-08-20 19:00:01.254000+00:00
# 1   8c40fdf063e02ad3b57a3c99a8348338dd0474da 2019-08-20 19:00:01.279000+00:00
# 6   c44e8d70d6c30c671d742ffa9a9e3e9231b5cc60 2019-08-20 19:00:03.815000+00:00
# 15  636c066e6c78b33d916a71403c6dd2394fb411fa 2019-08-20 19:00:05.583000+00:00
# 20  c44e8d70d6c30c671d742ffa9a9e3e9231b5cc60 2019-08-20 19:00:09.327000+00:00

# %%
csi = csi.sort_values(['publisherUserId', 'request.requestedAt'])

# %%
# drop client time column
csi = csi.drop(columns=['clientId','clientTime','customDimensions.clickTarget','customDimensions.selector','name',
                        'customDimensions.pageX','customDimensions.pageY'])

# %%
# group by everything except request.requestedAt (get max)
cols_to_group = list(set(csi.columns.values) - {'request.requestedAt'})
csi = csi.groupby(cols_to_group).agg({'request.requestedAt': 'max'}).reset_index()

# %%
# create next label
csi['customDimensions.nextLabel'] = csi.groupby('publisherUserId')['customDimensions.label'].shift(-1)

# %%
csi.loc[csi['publisherUserId'] == '87582cf449bcaaef8041a75520c50b3bc4fc5e69', :]
# Out:
#          customDimensions.documentWidth       pageId  \
# 1084313                            1686  flight.home
# 1085002                            1686  flight.home
# 1085004                            1686  flight.home
# 1085005                            1686  flight.home
# 1085008                            1686  flight.home
# ...                                 ...          ...
# 1406971                            2024  flight.list
# 1407007                            2024  flight.list
# 1407008                            2024  flight.list
# 1414370                            2049  flight.list
# 1416992                            2152  flight.list
#
#          customDimensions.viewportHeight  customDimensions.viewportWidth  \
# 1084313                              781                            1707
# 1085002                              831                            1707
# 1085004                              831                            1707
# 1085005                              831                            1707
# 1085008                              831                            1707
# ...                                  ...                             ...
# 1406971                              938                            2049
# 1407007                              998                            2049
# 1407008                              998                            2049
# 1414370                              998                            2049
# 1416992                              886                            1821
#
#          customDimensions.documentHeight customDimensions.label  \
# 1084313                             3269                   LOGO
# 1085002                             3068                   LOGO
# 1085004                             3181         NAV_BAR_LOG_IN
# 1085005                             3181         NAV_BAR_LOG_IN
# 1085008                             3181         NAV_BAR_LOG_IN
# ...                                  ...                    ...
# 1406971                             4989  FILTERS_TRANSIT_VISAS
# 1407007                             2885         NAV_BAR_LOG_IN
# 1407008                            42986                 SEARCH
# 1414370                             2885         NAV_BAR_LOG_IN
# 1416992                            52703         NAV_BAR_LOG_IN
#
#                          pageInitializationId  \
# 1084313  cd0d52c8-60a0-46cb-ac6d-8ba09e56db00
# 1085002  70be7f8b-4dd8-41aa-ba56-2f2f77b869c4
# 1085004  70be7f8b-4dd8-41aa-ba56-2f2f77b869c4
# 1085005  8226b258-a18a-48dc-9d1e-7e1d6a0ae296
# 1085008  fd3871c2-22e9-49c5-bd26-983dc522f39f
# ...                                       ...
# 1406971  9df601fe-a106-4e73-a0b4-dc56b426337c
# 1407007  cf519187-4b43-4a78-8b1d-ed7dd3aa44dc
# 1407008  69903b37-c5b5-4671-bd0a-df4b157248e8
# 1414370  cf519187-4b43-4a78-8b1d-ed7dd3aa44dc
# 1416992  75b08967-e862-4ca6-9359-45e08e3947d7
#
#                                   publisherUserId  \
# 1084313  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# 1085002  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# 1085004  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# 1085005  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# 1085008  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# ...                                           ...
# 1406971  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# 1407007  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# 1407008  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# 1414370  87582cf449bcaaef8041a75520c50b3bc4fc5e69
# 1416992  87582cf449bcaaef8041a75520c50b3bc4fc5e69
#
#                      request.requestedAt customDimensions.nextLabel
# 1084313 2019-08-20 01:52:53.977000+00:00                       LOGO
# 1085002 2019-08-21 03:13:14.273000+00:00             NAV_BAR_LOG_IN
# 1085004 2019-08-20 21:09:42.498000+00:00             NAV_BAR_LOG_IN
# 1085005 2019-08-19 22:14:34.586000+00:00             NAV_BAR_LOG_IN
# 1085008 2019-08-21 21:25:49.460000+00:00         FLIGHT_DESTINATION
# ...                                  ...                        ...
# 1406971 2019-10-09 23:05:34.957000+00:00             NAV_BAR_LOG_IN
# 1407007 2019-10-15 21:32:36.065000+00:00                     SEARCH
# 1407008 2019-10-07 22:23:22.046000+00:00             NAV_BAR_LOG_IN
# 1414370 2019-10-15 21:32:34.933000+00:00             NAV_BAR_LOG_IN
# 1416992 2019-08-25 23:15:42.042000+00:00                        NaN
#
# [309 rows x 10 columns]

# %%
csi.to_hdf('../dataframes/ClientSideInfos.hdf', key='csi', format='table')
